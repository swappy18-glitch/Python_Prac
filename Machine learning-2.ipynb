# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import sklearn
import scipy 
import seaborn as sns
sns.set()#overrides matplotlib graphs

# %%
df = pd.read_csv("1.01. Simple linear regression.csv")
df.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %%
y = df["GPA"]
x1 = df["SAT"]

# %%
ç

# %%
x = sm.add_constant(x1)
results = sm.OLS(y, x).fit()
results.summary()
# Out:
# /Users/swapnilramanna/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Tue, 22 Feb 2022   Prob (F-statistic):           7.20e-11
# Time:                        06:17:50   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# ...

# %%
plt.scatter(x1,y)
yhat = 0.0017*x1 + 0.275
fig = plt.plot(x1,yhat, lw = 4, c = "orange", label = "regression line")
plt.xlabel("SAT", fontsize = 20)
plt.ylabel("GPA", fontsize = 20)
plt.show()

# %%
plt.scatter(x1,y)
yhat = 0.0017*x1 + 0
fig = plt.plot(x1,yhat, lw = 4, c = "green", label = "regression line")
plt.xlabel("SAT", fontsize = 20)
plt.ylabel("GPA", fontsize = 20)
plt.xlim(0)
plt.ylim(0)
plt.show()

# %%
plt.scatter(x1,y)
yhat = 0*x1 + 0.275
fig = plt.plot(x1,yhat, lw = 4, c = "red", label = "regression line")
plt.xlabel("SAT", fontsize = 20)
plt.ylabel("GPA", fontsize = 20)
plt.show()

# %%
multi=pd.read_csv('1.02. Multiple linear regression.csv')
multi
# Out:
#      SAT  Rand 1,2,3   GPA
# 0   1714           1  2.40
# 1   1664           3  2.52
# 2   1760           3  2.54
# 3   1685           3  2.74
# 4   1693           2  2.83
# ..   ...         ...   ...
# 79  1936           3  3.71
# 80  1810           1  3.71
# 81  1987           3  3.73
# 82  1962           1  3.76
# 83  2050           2  3.81
#
# [84 rows x 3 columns]

# %%
y = multi["GPA"]
x1 = multi[["SAT","Rand 1,2,3"]]

# %%
x = sm.add_constant(x1)
results=sm.OLS(y,x).fit()
# Out:
# /Users/swapnilramanna/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.407
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     27.76
# Date:                Tue, 22 Feb 2022   Prob (F-statistic):           6.58e-10
# Time:                        06:28:18   Log-Likelihood:                 12.720
# No. Observations:                  84   AIC:                            -19.44
# Df Residuals:                      81   BIC:                            -12.15
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2960      0.417      0.710      0.480      -0.533       1.125
# ...

# %%
ef = pd.read_csv("1.03. Dummies.csv")
ef
# Out:
#      SAT   GPA Attendance
# 0   1714  2.40         No
# 1   1664  2.52         No
# 2   1760  2.54         No
# 3   1685  2.74         No
# 4   1693  2.83         No
# ..   ...   ...        ...
# 79  1936  3.71        Yes
# 80  1810  3.71        Yes
# 81  1987  3.73         No
# 82  1962  3.76        Yes
# 83  2050  3.81        Yes
#
# [84 rows x 3 columns]

# %%
ef2 = ef.copy()

# %%
ef2["Attendance"] = ef2["Attendance"].map({"Yes":0, "No":1})

# %%
ef2
# Out:
#      SAT   GPA  Attendance
# 0   1714  2.40           1
# 1   1664  2.52           1
# 2   1760  2.54           1
# 3   1685  2.74           1
# 4   1693  2.83           1
# ..   ...   ...         ...
# 79  1936  3.71           0
# 80  1810  3.71           0
# 81  1987  3.73           1
# 82  1962  3.76           0
# 83  2050  3.81           0
#
# [84 rows x 3 columns]

# %%
##Regression

# %%
y = ef2["GPA"]
x1 = ef2[["SAT","Attendance"]]

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# /Users/swapnilramanna/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     52.70
# Date:                Tue, 22 Feb 2022   Prob (F-statistic):           2.19e-15
# Time:                        10:44:32   Log-Likelihood:                 25.798
# No. Observations:                  84   AIC:                            -45.60
# Df Residuals:                      81   BIC:                            -38.30
# Df Model:                           2
# ...

# %%
plt.scatter(ef2["SAT"],y)
yhat_no =0.6439 + 0.0014 * ef2["SAT"]+0.2226 * 0#0.6439 IS TH EVALUE WHEN YOU INSERT 0 FOR THE EF2["Attendance"], because of zero attendance
yhat_yes = 0.8665 + 0.0014 * ef2["SAT"]+ 0.2226 * 1
fig = plt.plot(ef2["SAT"],yhat_no, lw = 2, c = '#006837')
fig = plt.plot(ef2["SAT"],yhat_yes, lw = 2, c = "#a50026")
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %%
plt.scatter(ef2["SAT"],y, c = ef2["Attendance"], cmap = 'RdYlGn_r')
yhat_no =0.6439 + 0.0014 * ef2["SAT"]+0.2226 * 0#0.6439 IS TH EVALUE WHEN YOU INSERT 0 FOR THE EF2["Attendance"], because of zero attendance
yhat_yes = 0.8665 + 0.0014 * ef2["SAT"]+ 0.2226 * 1
fig = plt.plot(ef2["SAT"],yhat_no, lw = 2, c = '#006837')
fig = plt.plot(ef2["SAT"],yhat_yes, lw = 2, c = "#a50026")
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %%
plt.scatter(ef2["SAT"],y, c = ef2["Attendance"], cmap = 'RdYlGn_r')
yhat_no =0.6439 + 0.0014 * ef2["SAT"]+0.2226 * 0#0.6439 IS TH EVALUE WHEN YOU INSERT 0 FOR THE EF2["Attendance"], because of zero attendance
yhat_yes = 0.8665 + 0.0014 * ef2["SAT"]+ 0.2226 * 1
yhat = 0.0017 * ef2["SAT"] + 0.275
fig = plt.plot(ef2["SAT"],yhat_no, lw = 2, c = '#006837', label = "Regression line")
fig = plt.plot(ef2["SAT"],yhat_yes, lw = 2, c = "#a50026", label = 'Regression line')
fig = plt.plot(ef2["SAT"],yhat,lw = 3, c = "#4C72B0", label ="Regression line")
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %%
d = pd.read_csv("Startups.csv")
d
# Out:
#     R&D Expenditure  Administration Expenditure  Marketing Expenditure  \
# 0         165349.20                   136897.80              471784.10
# 1         162597.70                   151377.59              443898.53
# 2         153441.51                   101145.55              407934.54
# 3         144372.41                   118671.85              383199.62
# 4         142107.34                    91391.77              366168.42
# 5         131876.90                    99814.71              362861.36
# 6         134615.46                   147198.87              127716.82
# 7         130298.13                   145530.06              323876.68
# 8         120542.52                   148718.95              311613.29
# 9         123334.88                   108679.17              304981.62
# 10        101913.08                   110594.11              229160.95
# 11        100671.96                    91790.61              249744.55
# ...

# %%
y = d["Profit"]
x1 = d["Marketing Expenditure"]

# %%
b = sm.add_constant(x1)
results = sm.OLS(y,b).fit()
results.summary()
# Out:
# /Users/swapnilramanna/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Tue, 22 Feb 2022   Prob (F-statistic):           4.38e-10
# Time:                        11:31:47   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# ...

# %%
plt.scatter(x1,y)
yhat = 0.2465 *x1 + 0
fig = plt.plot(x1,yhat, lw = 4, c = "orange", label = "regression line")
plt.xlabel("Marketing Expenditure", fontsize = 20)
plt.ylabel("Profit", fontsize = 20)
plt.show()

# %%
z = d["Profit"]
w1 = d[["Marketing Expenditure","R&D Expenditure"]]

# %%
w2 = sm.add_constant(w1)
results = sm.OLS(y,w2).fit()
results.summary()
# Out:
# /Users/swapnilramanna/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Tue, 22 Feb 2022   Prob (F-statistic):           2.16e-31
# Time:                        11:42:56   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# ...
